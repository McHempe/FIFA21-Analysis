# %% [markdown]
# # 01. Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os
import folium

# %%
# This command prompts matplotlib visuals to appear in the notebook.

# %matplotlib inline

# %% [markdown]
# # 02. Importing data

# %%
path = r'/Users/Hempe/Google Drive/CareerFoundry/6_Advanced Analytics & Dashboard Design/FIFA 21 Data Analysis/'

# %%
# Import FIFA 21 Data Set players_21_cleaned.csv
df_players_cleaned = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'players_21_cleaned.csv'), index_col = False)

# %%
# Import ".json" file for the whole world 

country_geo = r'/Users/Hempe/Google Drive/CareerFoundry/6_Advanced Analytics & Dashboard Design/FIFA 21 Data Analysis/02 Data/Original Data/countries.json'

# %%
country_geo
# Out:
# '/Users/Hempe/Google Drive/CareerFoundry/6_Advanced Analytics & Dashboard Design/FIFA 21 Data Analysis/02 Data/Original Data/countries.json'

# %%
pd.set_option('display.max_columns', None)
df_players_cleaned.head(5)
# Out:
#    Unnamed: 0  sofifa_id         short_name  \
# 0           0     158023           L. Messi
# 1           1      20801  Cristiano Ronaldo
# 2           2     200389           J. Oblak
# 3           3     188545     R. Lewandowski
# 4           4     190871          Neymar Jr
#
#                              long_name  age         dob  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33  1987-06-24        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05        187         83
# 2                            Jan Oblak   27  1993-01-07        188         87
# 3                   Robert Lewandowski   31  1988-08-21        184         80
# 4        Neymar da Silva Santos Júnior   28  1992-02-05        175         68
#
#   nationality            club_name             league_name  \
# 0   Argentina         FC Barcelona  Spain Primera Division
# 1    Portugal             Juventus         Italian Serie A
# ...

# %%
df_players_cleaned.shape
# Out:
# (18944, 96)

# %% [markdown]
# # 03. Data cleaning

# %%
# rename column "overall" to "overall_fifa_score"
df_players_cleaned.rename(columns = {'overall' : 'overall_fifa_score'}, inplace = True)

# %%
pd.set_option('display.max_columns', None)
df_players_cleaned.head(5)
# Out:
#    Unnamed: 0  sofifa_id         short_name  \
# 0           0     158023           L. Messi
# 1           1      20801  Cristiano Ronaldo
# 2           2     200389           J. Oblak
# 3           3     188545     R. Lewandowski
# 4           4     190871          Neymar Jr
#
#                              long_name  age         dob  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33  1987-06-24        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05        187         83
# 2                            Jan Oblak   27  1993-01-07        188         87
# 3                   Robert Lewandowski   31  1988-08-21        184         80
# 4        Neymar da Silva Santos Júnior   28  1992-02-05        175         68
#
#   nationality            club_name             league_name  \
# 0   Argentina         FC Barcelona  Spain Primera Division
# 1    Portugal             Juventus         Italian Serie A
# ...

# %% [markdown]
# # 04. Changing a Variable’s Data Type

# %%
# changing overall_fifa_score data type to integer
df_players_cleaned['overall_fifa_score'] = df_players_cleaned['overall_fifa_score'].astype('int')

# %%
df_players_cleaned['overall_fifa_score'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # 05. Map setup

# %%
# Create a data frame with just the nationalities and the overall fifa scores we want plotted

data_to_plot = df_players_cleaned[['nationality','overall_fifa_score']]
data_to_plot.head()
# Out:
#   nationality  overall_fifa_score
# 0   Argentina                  93
# 1    Portugal                  92
# 2    Slovenia                  91
# 3      Poland                  91
# 4      Brazil                  91

# %%
# Setup a folium map at a high-level zoom
map = folium.Map(location = [100, 0], zoom_start = 1.5)

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
map.choropleth(geo_data = country_geo, data = data_to_plot,
             columns = ['nationality', 'overall_fifa_score'],
             key_on = 'Feature.properties.name', 
            # this part is very important - check your json file to see where the KEY is located
             fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
             legend_name = "overall_fifa_score")
# Out:
# /Users/Hempe/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-40e4987a13c5> in <module>
#       3
#       4 # Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
# ----> 5 map.choropleth(geo_data = country_geo, data = data_to_plot,
#       6              columns = ['nationality', 'overall_fifa_score'],
#       7              key_on = 'Feature.properties.name',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     414         )
# ...

# %% [markdown]
# # 06. Export cleaned data

# %%
# Export dataframe in “Prepared Data” folder.
df_players_cleaned.to_csv(os.path.join(path, '02 Data','Prepared Data', 'players_21_cleaned_new.csv'))
